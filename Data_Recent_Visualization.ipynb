# %% [markdown]
# <a href="https://colab.research.google.com/github/anjilakarkigit/dataVisualization/blob/main/Data_Recent_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # World Food Waste and Hunger

# %% [markdown]
# Anjila Karki
#
# East Central University
#
# Spring 2022
#
# CPSMA 4313
#
# Instructor: Dr. Nicholas Jacob

# %% [markdown]
# >**Abstract**= In this part of the project I am going to look at different visualization involving waste of food around and the world hunger and compare if the wasted food can be used to solve the problem.

# %% [markdown]
# **Introduction**
#
# Food waste on a global scale is a huge problem with huge financial, ethical, and environmental repercussions. The causes range from uneven roads to overly-picky clients, but whatever the reason, we can all help to address this global problem.An estimated 1.3 billion tonnes of food is wasted globally each year, one third of all food produced for human consumption, according to the Food and Agriculture Organization (FAO) of the United Nations.The amount of food lost or wasted costs 2.6 trillion USD annually and is more than enough to feed all the 815 million hungry people in the world – four times over.
#
# For this project I will be looking at different Visualization on the world food waste and hunger issue.

# %% [markdown]
# **Statista and who are they?**
#
# I chose Statista as the source of my data visualization because, I believe it is a great source of visualization and meet the requirement of graphical excellence. No doubt the report is updated in a timely manner. Here is the [link](https://https://www.statista.com/) of the website I used for my visualization, where you can also find more and has current information of the above topic.. They have large amount of data and charts which makes it great place to look for visualization charts.

# %% [markdown]
# **Visual Capitalist**
#
# I chose Visual Capitalist as another data visualization source since I believe it is an excellent source of visualization and meets the graphical perfection standard.
# Visual Capitalist creates and curates visual content focused on latest trends in business and investing. It publishes news, research, and data using visual methods like infographics, data visualization, and charts.It stands for a world where data can be better understood by everyone. Alll the source and the data on this platform are free and easy to use.

# %% [markdown]
# ![Screen Shot 2022-04-22 at 10.22.53 PM.png](data:image/png;base64,...)

# %% [markdown]
# Here, on the first chart we can see the total number of people hungry in the world every 2 years from 2008. The world hunger population was highest on 2008 and start to dip and has rises since 2015 according to the graph. I think the visualization is excellent because the graph look very simple yet it has so much information packed trough the time of 14 years. The graph doesnot show the actual numbe of people hungry but has a preety much accurate number of visual.I think it is really hard to get the exact number of hungry people of the whole world.
#
#  The link to the article is https://www.visualcapitalist.com/interactive-map-tracking-global-hunger-and-food-insecurity/

# %% [markdown]
# ![Screen Shot 2022-04-22 at 10.34.01 PM.png](data:image/png;base64,...)

# %% [markdown]
# Here, on the second chart we can see the top countries on food waste per year in tons, in which china and india are leading the the show with vast margin. This visualization is visually pleasing and provides us with tons of information. If we see at the bottom of the bar graph the main souce of the data is from UNEP food waste index report from 2021.It includes all the information explicitly. As we can tell both of them is plotted using bar-graph. The use of color, symbol, labels, pictures are done appropriately. I chose this graph because it is informative and story telling.Rather than clutterign the chart with lot of data the visualization has just the right amount of infomation. By looking at the visualization we can also see the relation of the chart with the first chart.
#
# link to this is
# https://www.statista.com/chart/24350/total-annual-household-waste-produced-in-selected-countries/

# %% [markdown]
# **Why should both of the graph be considered as a great visualization? What are the similarities?**
#
# Both graphs are great. Both are wonderful renderings in their own right, in my opinion. Each piece of data is presented in a logical sequence. It has great graphics and is easy to use. In terms of similarities, I've already noted in the preceding graph that they're both bar-plots multiple times. In fact, both graphs use the same data source. The x-axis and y-axis labels are identical on both. The source of the graph, as well as the topic, are both stated explicitly. The bar is designated with the appropriate unit. Furthermore, both graphs are outstanding in terms of quality.

# %% [markdown]
# **Graphical Excellence of Both Graph**
#
# Graphical excellence is crucial and a great technique to make a critique about the graph.I think both the visualization show graphical excellence because it is well designed with substantive data and design. All the topic are explained accurately  and are easy to understand.The graph's source, as well as the topic, is explicitly noted. The proper unit is labeled on the bar. Differetn color code are used to remove any misunderstanding on the charts.

# %% [markdown]
# **Presentation of data in the graph**
#
# The bar-graph is plainly visible while looking at the data. As we can see, the graph is descriptive, and we can determine what is going on in it without having to spend a lot of time looking it up. The graph condenses a lot of information into one graph and presents it in a logical and efficient manner.
#
# I would also like to add the data dynamically presented. As you look through the graph it takes you through the entire timeline of world hunger from 2006 to 2020. With the help of images and numbers the presentation becomes more effective rather than jst plain numbers.

# %% [markdown]
# **The information on the graph**
#
# The graph is the perfect size, and the method used is both logical and ideal. It has all of the information that a good graph should have. Because the graph is nicely created in that amount of space, an audience can utilize it to create a tale. The graph is the right size for inclusion in a newsletter or article. Even if the graph's size is enlarged, I don't believe it will change the graph's appearance or information.

# %% [markdown]
# # Conclusion
#
# Food waste is a problem because it harms the environment by contributing to global warming and climate change when food waste is added to landfills and produces the greenhouse gas methane.
#
# I have used two visualization forr the project that provides information on the tpoic of world hunger. I have gained various knowledge on how the graphical excellence effect the article and how they help to potray the article.

# %% [markdown]
# # Refrences
#
# - https://www.visualcapitalist.com/interactive-map-tracking-global-hunger-and-food-insecurity/
#
# - https://www.statista.com/chart/24350/total-annual-household-waste-produced-in-selected-countries/
#
# - https://www.statista.com/chartoftheday/Food%20Waste/
#
# - https://www.weforum.org/agenda/2021/07/world-hunger-undernourished-food-security
