# %% [markdown]
# <a href="https://colab.research.google.com/github/anjilakarkigit/dataVisualization/blob/main/quiz_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screen Shot 2022-03-25 at 8.36.38 PM.png](data:image/png;base64,...)

# %% [markdown]
# https://www.statista.com/chart/24965/share-of-smokers-and-world-population-by-country/

# %% [markdown]
# The pie chart above shows the countries with most number of smokers. the graph only took data from 7 different contries and labled other as the other contries and donot have any data from those countries. I think since it doesn't have data from other contries it would not be accurate. They took data from most big contries because of their large number of population and high chances of smoker in those countries. But apart form that the chart look clean visually and the data entered in the look right.

# %% [markdown]
# ![picture2.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# https://www.imf.org/external/pubs/ft/fandd/2020/09/infographic-global-hunger-crisis-behsudi.htm

# %% [markdown]
# As the pandemic roils economies and strains public health systems, the impact is most prominent in vulnerable countries, where fears of a “hunger pandemic” are growing. on the graphs above it  shows how the pandemic has impacted on the world hunger issues.on the first part it shows numbe of population effected by the the issue. The graph is easy to understand and the graph are not off topic. there are two parameters one acutal number of people in millions and on the other side it shows percent wise. I think the data look significant , but the only thing I would want ot see would be some perivious data to compare the percent of increase. Rather than that I think the graph does preety good job on visualization explaining the theme.
