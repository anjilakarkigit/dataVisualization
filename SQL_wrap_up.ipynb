# %% [markdown]
# <a href="https://colab.research.google.com/github/anjilakarkigit/dataVisualization/blob/main/SQL_wrap_up.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# %%bigquery --project data-visualization-class-sql
# SELECT *
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# LIMIT 5
# Out:
#       trip_id  ... duration_minutes
# 0  9900289692  ...               39
# 1  9900285987  ...               31
# 2  9900285989  ...               31
# 3  9900285991  ...               30
# 4  9900286140  ...               19
#
# [5 rows x 9 columns]

# %%
# %%bigquery --project data-visualization-class-sql
# SELECT *
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_stations`
# LIMIT 4
# Out:
#    station_id  ...             modified_date
# 0        3464  ... 2021-01-04 12:00:00+00:00
# 1        2500  ... 2021-01-04 12:00:00+00:00
# 2        2536  ... 2021-01-04 12:00:00+00:00
# 3        2538  ... 2021-01-04 12:00:00+00:00
#
# [4 rows x 14 columns]

# %% [markdown]
# What is the subscriber_type for most popular start station and is the most popular subscriber type also popular in most popular start station?

# %%
# %%bigquery --project data-visualization-class-sql
# SELECT COUNT(start_station_name) as count, start_station_name as name, subscriber_type as subs
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# GROUP BY name, subs
# ORDER BY count DESC
# Out:
#       count                    name                               subs
# 0     70855    21st & Speedway @PCL            U.T. Student Membership
# 1     26611  Dean Keeton & Speedway            U.T. Student Membership
# 2     23283       23rd & Rio Grande            U.T. Student Membership
# 3     22093    Riverside @ S. Lamar                            Walk Up
# 4     21933            22nd & Pearl            U.T. Student Membership
# ...     ...                     ...                                ...
# 4480      1                3rd/West                        Annual Pass
# 4481      1             26th/Nueces                  Annual Membership
# 4482      1             26th/Nueces  Local365 Youth (age 13-17 riders)
# 4483      1             26th/Nueces                               None
# 4484      1           Nueces & 26th  Local365 Youth (age 13-17 riders)
#
# [4485 rows x 3 columns]

# %% [markdown]
# Here I see that UT student membership is most use subsriber type and 21st & speedway @pcl is the most popular start station combined.

# %%
# %%bigquery --project data-visualization-class-sql
# SELECT COUNT(subscriber_type) as count,subscriber_type as subs
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# GROUP BY subs
# ORDER BY count DESC
# Out:
#      count                                 subs
# 0   374151                              Walk Up
# 1   289288              U.T. Student Membership
# 2   260376                             Local365
# 3   108672       24-Hour Kiosk (Austin B-cycle)
# 4    69062                              Local30
# ..     ...                                  ...
# 72       2              Annual Pass (30 minute)
# 73       1  24-Hour Membership (Austin B-cycle)
# 74       1          Heartland Pass (Annual Pay)
# 75       1         Heartland Pass (Monthly Pay)
# 76       0                                 None
#
# [77 rows x 2 columns]

# %% [markdown]
# But the result for most popular subscriber type is Walk up.

# %%
# %%bigquery --project data-visualization-class-sql
# SELECT COUNT(start_station_name) as count, start_station_name as name
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# GROUP BY name
# ORDER BY count DESC
# Out:
#      count                      name
# 0    72799      21st & Speedway @PCL
# 1    40635      Riverside @ S. Lamar
# 2    36520  City Hall / Lavaca & 2nd
# 3    35307            2nd & Congress
# 4    34758      Rainey St @ Cummings
# ..     ...                       ...
# 188      4           Marketing Event
# 189      2             Eeyore's 2018
# 190      1                    Stolen
# 191      1             Eeyore's 2017
# 192      1     cesar Chavez/Congress
#
# [193 rows x 2 columns]

# %% [markdown]
# Also the most popular start station is 21st & Speedway @PCL . However the results do not match with the outcome I am looking for. I am totally confused here.
