# %% [markdown]
# <a href="https://colab.research.google.com/github/anjilakarkigit/dataVisualization/blob/main/twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.19.3-py2.py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 4.3 MB/s
# Installing collected packages: twitter
# Successfully installed twitter-1.19.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
 # !cp drive/MyDrive/config.py .

# %%
import config
import twitter
CONSUMER_KEY = config.CONSUMER_KEY
CONSUMER_SECRET = config.CONSUMER_SECRET
OAUTH_TOKEN = config.OAUTH_TOKEN
OAUTH_TOKEN_SECRET = config.OAUTH_TOKEN_SECRET
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

mathcs_twitter_api = twitter.Twitter(auth=auth)

# %% [markdown]
# 1.Find the top trending 10 topics in the world and display them by name

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = mathcs_twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = mathcs_twitter_api.trends.place(_id=US_WOE_ID)

for i in range(10):
    print(world_trends[0]['trends'][i]['query'])
# Out:
# %23WWERaw
# %22Kurt+Zouma%22
# %23gfvip
# %22Matheus+Nascimento%22
# %23ByeGoodBye
# %22Faz+o+M%22
# %22Dennis+Allen%22
# %23BEFIRST
# %23HarshRealityNosis
# %22Chad+Gable%22

# %% [markdown]
# Search for your favorite show, actor, sports team or player and see what twitter is saying about them.

# %%
#  Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.
import json


q = '#EmilyInParis'

count = 1000

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = mathcs_twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = mathcs_twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses, indent=4))
# Out:
# Streaming output truncated to the last 5000 lines.
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "pt",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 119186803,
#             "id_str": "119186803",
#             "name": "Lucas Bertoldo",
#             "screen_name": "Lucas_Bertoldo",
#             "location": "",
#             "description": "",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 440,
#             "friends_count": 1641,
#             "listed_count": 32,
#             "created_at": "Tue Mar 02 22:49:20 +0000 2010",
#             "favourites_count": 6319,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 9300,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#             "profile_background_tile": true,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1485100457177624577/OJo53WJo_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1485100457177624577/OJo53WJo_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/119186803/1615826629",
#             "profile_link_color": "876ECC",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "8F2988",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 1,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "pt"
#     },
#     {
#         "created_at": "Sun Feb 06 23:38:02 +0000 2022",
#         "id": 1490469864796041218,
#         "id_str": "1490469864796041218",
#         "text": "OH GOD he\u2019s so hot #EmilyInParis https://t.co/GtEBw6M3sJ",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "EmilyInParis",
#                     "indices": [
#                         19,
#                         32
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1490469857598521344,
#                     "id_str": "1490469857598521344",
#                     "indices": [
#                         33,
#                         56
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FK82cEqWQAAUV3-.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FK82cEqWQAAUV3-.jpg",
#                     "url": "https://t.co/GtEBw6M3sJ",
#                     "display_url": "pic.twitter.com/GtEBw6M3sJ",
#                     "expanded_url": "https://twitter.com/enchantedfeels/status/1490469864796041218/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 390,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1052,
#                             "h": 1835,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 688,
#                             "h": 1200,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1490469857598521344,
#                     "id_str": "1490469857598521344",
#                     "indices": [
#                         33,
#                         56
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FK82cEqWQAAUV3-.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FK82cEqWQAAUV3-.jpg",
#                     "url": "https://t.co/GtEBw6M3sJ",
#                     "display_url": "pic.twitter.com/GtEBw6M3sJ",
#                     "expanded_url": "https://twitter.com/enchantedfeels/status/1490469864796041218/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 390,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1052,
#                             "h": 1835,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 688,
#                             "h": 1200,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1914831828,
#             "id_str": "1914831828",
#             "name": "alicia",
#             "screen_name": "enchantedfeels",
#             "location": "she/her",
#             "description": "i watch too many tv shows | @tropicalswift",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 2379,
#             "friends_count": 70,
#             "listed_count": 59,
#             "created_at": "Sat Sep 28 17:57:12 +0000 2013",
#             "favourites_count": 26513,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 10639,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": true,
#             "profile_background_color": "1F94CF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": true,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1487849807372816386/Z0MQ9biM_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1487849807372816386/Z0MQ9biM_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1914831828/1638045642",
#             "profile_link_color": "9266CC",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "regular",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 1,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Sun Feb 06 23:27:44 +0000 2022",
#         "id": 1490467275182333954,
#         "id_str": "1490467275182333954",
#         "text": "OK after watching a bit can I just say I don't find Gabriel boring at all... He's.. peaceful.. and that's refreshing\n#EmilyInParis",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "EmilyInParis",
#                     "indices": [
#                         117,
#                         130
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 24915311,
#             "id_str": "24915311",
#             "name": "Shaakira\ud83d\udd4a\ufe0f",
#             "screen_name": "shaakimellow",
#             "location": "South Africa",
#             "description": "The lights are on but nobody's home",
#             "url": "https://t.co/MK3XF8wK6L",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/MK3XF8wK6L",
#                             "expanded_url": "https://curiouscat.me/shaakimellow",
#                             "display_url": "curiouscat.me/shaakimellow",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 739,
#             "friends_count": 1225,
#             "listed_count": 2,
#             "created_at": "Tue Mar 17 17:16:53 +0000 2009",
#             "favourites_count": 50083,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 34674,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "151B54",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1484646262142033930/sHS6nmA7_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1484646262142033930/sHS6nmA7_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/24915311/1641413803",
#             "profile_link_color": "7D0552",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "DBDBB6",
#             "profile_text_color": "04098F",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Sun Feb 06 23:27:44 +0000 2022",
#         "id": 1490467272703586306,
#         "id_str": "1490467272703586306",
#         "text": "BREAKING:  After hearing a review from #PaytonManning, I\u2019m watching #EmilyInParis and it\u2026is\u2026GOOD!",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "PaytonManning",
#                     "indices": [
#                         39,
#                         53
#                     ]
#                 },
#                 {
#                     "text": "EmilyInParis",
#                     "indices": [
#                         68,
#                         81
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 756514723873562624,
#             "id_str": "756514723873562624",
#             "name": "dk2's EXCLUSIVE Private Society",
#             "screen_name": "CondescendingDK",
#             "location": "A place you're not invited to.",
#             "description": "Here to talk sports & other things with #YouPeople. #CBJ @athletics #DallasCowboys #thisshiprocks #dk2exclusive I/Me/Mine",
#             "url": "https://t.co/YkFz9339gB",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/YkFz9339gB",
#                             "expanded_url": "https://m.youtube.com/channel/UCApIXJPfcHDK6BkTWVVjHvQ",
#                             "display_url": "m.youtube.com/channel/UCApIX\u2026",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 351,
#             "friends_count": 181,
#             "listed_count": 1,
#             "created_at": "Fri Jul 22 15:42:20 +0000 2016",
#             "favourites_count": 10396,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 7376,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1490091951512821766/v7hr8S45_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1490091951512821766/v7hr8S45_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/756514723873562624/1641706650",
#             "profile_link_color": "ABB8C2",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 1,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Sun Feb 06 23:17:40 +0000 2022",
#         "id": 1490464740631461890,
#         "id_str": "1490464740631461890",
#         "text": "Me desespera lo mal que se viste Emily #EmilyInParis",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "EmilyInParis",
#                     "indices": [
#                         39,
#                         52
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "es",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 3731766022,
#             "id_str": "3731766022",
#             "name": "La Roux",
#             "screen_name": "letigarciaroux",
#             "location": "Asuncion, Paraguay",
#             "description": "Tenemos lo que creemos merecer \ud83d\udcab",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 273,
#             "friends_count": 598,
#             "listed_count": 1,
#             "created_at": "Mon Sep 21 20:32:12 +0000 2015",
#             "favourites_count": 5164,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 7093,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1356413479155077125/FPeuqXse_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1356413479155077125/FPeuqXse_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/3731766022/1581168328",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 1,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "es"
#     },
#     {
#         "created_at": "Sun Feb 06 23:14:39 +0000 2022",
#         "id": 1490463980602626049,
#         "id_str": "1490463980602626049",
#         "text": "I\u2019m in fucking catarsis con #EmilyInParis y el amor by distance que pedo, me identifico \ud83d\ude26\ud83d\ude2e https://t.co/tlWsoHo8vF",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "EmilyInParis",
#                     "indices": [
#                         28,
#                         41
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1490463968208510989,
#                     "id_str": "1490463968208510989",
#                     "indices": [
#                         91,
#                         114
#                     ],
#                     "media_url": "http://pbs.twimg.com/tweet_video_thumb/FK8xFQ-WYA0oU5v.jpg",
#                     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/FK8xFQ-WYA0oU5v.jpg",
#                     "url": "https://t.co/tlWsoHo8vF",
#                     "display_url": "pic.twitter.com/tlWsoHo8vF",
#                     "expanded_url": "https://twitter.com/leo_J8X/status/1490463980602626049/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "medium": {
#                             "w": 498,
#                             "h": 280,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 498,
#                             "h": 280,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 498,
#                             "h": 280,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1490463968208510989,
#                     "id_str": "1490463968208510989",
#                     "indices": [
#                         91,
#                         114
#                     ],
#                     "media_url": "http://pbs.twimg.com/tweet_video_thumb/FK8xFQ-WYA0oU5v.jpg",
#                     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/FK8xFQ-WYA0oU5v.jpg",
#                     "url": "https://t.co/tlWsoHo8vF",
#                     "display_url": "pic.twitter.com/tlWsoHo8vF",
#                     "expanded_url": "https://twitter.com/leo_J8X/status/1490463980602626049/photo/1",
#                     "type": "animated_gif",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "medium": {
#                             "w": 498,
#                             "h": 280,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 498,
#                             "h": 280,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 498,
#                             "h": 280,
#                             "resize": "fit"
#                         }
#                     },
#                     "video_info": {
#                         "aspect_ratio": [
#                             249,
#                             140
#                         ],
#                         "variants": [
#                             {
#                                 "bitrate": 0,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/tweet_video/FK8xFQ-WYA0oU5v.mp4"
#                             }
#                         ]
#                     }
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 151638310,
#             "id_str": "151638310",
#             "name": "Leo VFX \ud83c\udf41",
#             "screen_name": "leo_J8X",
#             "location": "Mexico City et Ottawa-Gatineau",
#             "description": "3D Designer | Motion designer\n \ud83c\uddf2\ud83c\uddfd et \ud83c\udde8\ud83c\udde6 my two biggest loves.\nL\u00e2cher prise et profiter le pr\u00e9sent \u2764\ufe0f",
#             "url": "https://t.co/MxpbIMFLi8",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/MxpbIMFLi8",
#                             "expanded_url": "https://www.instagram.com/leo.ca1/",
#                             "display_url": "instagram.com/leo.ca1/",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 58,
#             "friends_count": 162,
#             "listed_count": 0,
#             "created_at": "Thu Jun 03 22:08:30 +0000 2010",
#             "favourites_count": 2318,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 1829,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "170061",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#             "profile_background_tile": true,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1406803774128197641/oVKJ9yyJ_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1406803774128197641/oVKJ9yyJ_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/151638310/1543469221",
#             "profile_link_color": "ABB8C2",
#             "profile_sidebar_border_color": "DECFFF",
#             "profile_sidebar_fill_color": "3E3982",
#             "profile_text_color": "756DA3",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Sun Feb 06 22:57:35 +0000 2022",
#         "id": 1490459685408882688,
#         "id_str": "1490459685408882688",
#         "text": "I\u2019m watching @emilyinpar #EmilyInParis  and my@mind is blowing hahaha all the French things and also the memories a\u2026 https://t.co/q7gb6AtNve",
#         "truncated": true,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "EmilyInParis",
#                     "indices": [
#                         25,
#                         38
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/q7gb6AtNve",
#                     "expanded_url": "https://twitter.com/i/web/status/1490459685408882688",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         117,
#                         140
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 151638310,
#             "id_str": "151638310",
#             "name": "Leo VFX \ud83c\udf41",
#             "screen_name": "leo_J8X",
#             "location": "Mexico City et Ottawa-Gatineau",
#             "description": "3D Designer | Motion designer\n \ud83c\uddf2\ud83c\uddfd et \ud83c\udde8\ud83c\udde6 my two biggest loves.\nL\u00e2cher prise et profiter le pr\u00e9sent \u2764\ufe0f",
#             "url": "https://t.co/MxpbIMFLi8",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/MxpbIMFLi8",
#                             "expanded_url": "https://www.instagram.com/leo.ca1/",
#                             "display_url": "instagram.com/leo.ca1/",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 58,
#             "friends_count": 162,
#             "listed_count": 0,
#             "created_at": "Thu Jun 03 22:08:30 +0000 2010",
#             "favourites_count": 2318,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 1829,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "170061",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#             "profile_background_tile": true,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1406803774128197641/oVKJ9yyJ_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1406803774128197641/oVKJ9yyJ_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/151638310/1543469221",
#             "profile_link_color": "ABB8C2",
#             "profile_sidebar_border_color": "DECFFF",
#             "profile_sidebar_fill_color": "3E3982",
#             "profile_text_color": "756DA3",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 2,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Sun Feb 06 22:51:25 +0000 2022",
#         "id": 1490458136012013571,
#         "id_str": "1490458136012013571",
#         "text": "Finally ho finito di vedere la seconda stagione di #EmilyInParis",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "EmilyInParis",
#                     "indices": [
#                         51,
#                         64
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "it",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 633957080,
#             "id_str": "633957080",
#             "name": "Elena Formisano",
#             "screen_name": "EllenFormi",
#             "location": "",
#             "description": "Be in love with your life.",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 165,
#             "friends_count": 232,
#             "listed_count": 2,
#             "created_at": "Thu Jul 12 18:50:32 +0000 2012",
#             "favourites_count": 10317,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 9524,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1454833804791648257/3Qepsvmy_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1454833804791648257/3Qepsvmy_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/633957080/1383352476",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "it"
#     },
#     {
#         "created_at": "Sun Feb 06 22:47:59 +0000 2022",
#         "id": 1490457272438427650,
#         "id_str": "1490457272438427650",
#         "text": "I've just watched episode S01 | E09 of Emily in Paris! #emilyinparis  https://t.co/SAWyquEbx4 #tvtime https://t.co/DY4gvC405e",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "emilyinparis",
#                     "indices": [
#                         55,
#                         68
#                     ]
#                 },
#                 {
#                     "text": "tvtime",
#                     "indices": [
#                         94,
#                         101
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/SAWyquEbx4",
#                     "expanded_url": "https://tvtime.com/r/28IeM",
#                     "display_url": "tvtime.com/r/28IeM",
#                     "indices": [
#                         70,
#                         93
#                     ]
#                 }
#             ],
#             "media": [
#                 {
#                     "id": 1490457270777430019,
#                     "id_str": "1490457270777430019",
#                     "indices": [
#                         102,
#                         125
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FK8q_bGWQAMDX1E.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FK8q_bGWQAMDX1E.jpg",
#                     "url": "https://t.co/DY4gvC405e",
#                     "display_url": "pic.twitter.com/DY4gvC405e",
#                     "expanded_url": "https://twitter.com/Iovestorytv/status/1490457272438427650/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 600,
#                             "h": 335,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 600,
#                             "h": 335,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 600,
#                             "h": 335,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1490457270777430019,
#                     "id_str": "1490457270777430019",
#                     "indices": [
#                         102,
#                         125
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FK8q_bGWQAMDX1E.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FK8q_bGWQAMDX1E.jpg",
#                     "url": "https://t.co/DY4gvC405e",
#                     "display_url": "pic.twitter.com/DY4gvC405e",
#                     "expanded_url": "https://twitter.com/Iovestorytv/status/1490457272438427650/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 600,
#                             "h": 335,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 600,
#                             "h": 335,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 600,
#                             "h": 335,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://www.tvtime.com\" rel=\"nofollow\">TV Time, TV show tracker</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 535609360,
#             "id_str": "535609360",
#             "name": "Mica (Taylor's Version) \ud83c\udf3b",
#             "screen_name": "Iovestorytv",
#             "location": "23 | Arg",
#             "description": "Back when you fit my poems like a perfect rhyme",
#             "url": "https://t.co/1lCIXBhifz",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/1lCIXBhifz",
#                             "expanded_url": "https://letterboxd.com/micasr/",
#                             "display_url": "letterboxd.com/micasr/",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 11028,
#             "friends_count": 1974,
#             "listed_count": 44,
#             "created_at": "Sat Mar 24 18:52:12 +0000 2012",
#             "favourites_count": 31748,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 183166,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1486130466960908288/o0P_7_3N_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1486130466960908288/o0P_7_3N_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/535609360/1643156088",
#             "profile_link_color": "000000",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": false,
#             "has_extended_profile": true,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "regular",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Sun Feb 06 22:24:28 +0000 2022",
#         "id": 1490451354728423424,
#         "id_str": "1490451354728423424",
#         "text": "I've just watched episode S01 | E08 of Emily in Paris! #emilyinparis  https://t.co/b9tiu1Hovx #tvtime https://t.co/95g8PGnlcV",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "emilyinparis",
#                     "indices": [
#                         55,
#                         68
#                     ]
#                 },
#                 {
#                     "text": "tvtime",
#                     "indices": [
#                         94,
#                         101
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/b9tiu1Hovx",
#                     "expanded_url": "https://tvtime.com/r/28HYE",
#                     "display_url": "tvtime.com/r/28HYE",
#                     "indices": [
#                         70,
#                         93
#                     ]
#                 }
#             ],
#             "media": [
#                 {
#                     "id": 1490451353264701441,
#                     "id_str": "1490451353264701441",
#                     "indices": [
#                         102,
#                         125
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FK8lm-pXwAEMhW7.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FK8lm-pXwAEMhW7.jpg",
#                     "url": "https://t.co/95g8PGnlcV",
#                     "display_url": "pic.twitter.com/95g8PGnlcV",
#                     "expanded_url": "https://twitter.com/Iovestorytv/status/1490451354728423424/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 600,
#                             "h": 335,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 600,
#                             "h": 335,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 600,
#                             "h": 335,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1490451353264701441,
#                     "id_str": "1490451353264701441",
#                     "indices": [
#                         102,
#                         125
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FK8lm-pXwAEMhW7.jpg",
# ...
#             ],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1712663304,
#             "id_str": "1712663304",
#             "name": "Thandeka Jolie-Pitt",
#             "screen_name": "Thanderkah",
#             "location": "On the road to success",
#             "description": "The God in me recognizes the one above.",
#             "url": "https://t.co/7IDoW8Ah9W",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/7IDoW8Ah9W",
#                             "expanded_url": "https://twitter.com",
#                             "display_url": "twitter.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 1309,
#             "friends_count": 640,
#             "listed_count": 4,
#             "created_at": "Fri Aug 30 12:58:30 +0000 2013",
#             "favourites_count": 1522,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 28254,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/869722398140116993/4GXshdqv_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/869722398140116993/4GXshdqv_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1712663304/1580653979",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Fri Feb 04 17:58:19 +0000 2022",
#             "id": 1489659597514235909,
#             "id_str": "1489659597514235909",
#             "text": "IF EMILY DOESNT CHOOSE ALFIE I WILL . #EmilyInParis",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "EmilyInParis",
#                         "indices": [
#                             38,
#                             51
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 4245654025,
#                 "id_str": "4245654025",
#                 "name": "chris",
#                 "screen_name": "Christinaib_",
#                 "location": "Lebanon",
#                 "description": "\ud83c\udfce\ud83c\udfce, @scuderiaferrari CL SUPREMACY @charles_leclerc",
#                 "url": "https://t.co/oZenbtaYkQ",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/oZenbtaYkQ",
#                                 "expanded_url": "https://instagram.com/christinaibrikji?igshid=koujgcugvtuz",
#                                 "display_url": "instagram.com/christinaibrik\u2026",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 2838,
#                 "friends_count": 1017,
#                 "listed_count": 27,
#                 "created_at": "Sun Nov 15 12:39:39 +0000 2015",
#                 "favourites_count": 14000,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 11755,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1471474228461547532/eOHmJZUS_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1471474228461547532/eOHmJZUS_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/4245654025/1639326312",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 7,
#             "favorite_count": 22,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 7,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Sun Feb 06 18:49:53 +0000 2022",
#         "id": 1490397352225562633,
#         "id_str": "1490397352225562633",
#         "text": "SUNDAY (as it was meant to be spent) \ud83d\udd70 \n12 in the morning~ won 14-6 in a five-a-side match\n3pm~ \u2018Shredding my legs\u2019\u2026 https://t.co/zhoB81kyob",
#         "truncated": true,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/zhoB81kyob",
#                     "expanded_url": "https://twitter.com/i/web/status/1490397352225562633",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         117,
#                         140
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 992624379677822976,
#             "id_str": "992624379677822976",
#             "name": "Zayam",
#             "screen_name": "Blyv1k",
#             "location": "Karachi, Pakistan",
#             "description": "\ud83d\udcca Business major // Philomath, fond of company | Into: \ud83c\udfae \u26bd\ufe0f \ud83c\udfc0 \ud83c\udfce",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 12,
#             "friends_count": 276,
#             "listed_count": 0,
#             "created_at": "Sat May 05 04:37:48 +0000 2018",
#             "favourites_count": 74,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 109,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1114237204501602305/zlhP-anV_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1114237204501602305/zlhP-anV_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/992624379677822976/1554489824",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Sun Feb 06 18:31:00 +0000 2022",
#         "id": 1490392598413987841,
#         "id_str": "1490392598413987841",
#         "text": "Here are the Emily In Paris posts. These are just some of the difficult words (3-5 for each episode) I found could\u2026 https://t.co/2HwHQhNiFm",
#         "truncated": true,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/2HwHQhNiFm",
#                     "expanded_url": "https://twitter.com/i/web/status/1490392598413987841",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         116,
#                         139
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1325284670158729216,
#             "id_str": "1325284670158729216",
#             "name": "Officiellement Fran\u00e7ais",
#             "screen_name": "OfficialyFrench",
#             "location": "New Delhi, India",
#             "description": "Officially French\u25aa\ufe0f\nNouvelles id\u00e9es, technique unique\u2728\n\ud83d\udcf1Daily grammar and vocab\n\u2728Teaching French for A1- A2 levels\nCorrections are welcome via DM\ud83e\udd17",
#             "url": "https://t.co/dw3nl6qesW",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/dw3nl6qesW",
#                             "expanded_url": "https://linktr.ee/Officially_French",
#                             "display_url": "linktr.ee/Officially_Fre\u2026",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 431,
#             "friends_count": 106,
#             "listed_count": 10,
#             "created_at": "Sun Nov 08 03:51:12 +0000 2020",
#             "favourites_count": 486,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 978,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1482724330119503880/9-mtHO07_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1482724330119503880/9-mtHO07_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1325284670158729216/1642343956",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     }
# ]
